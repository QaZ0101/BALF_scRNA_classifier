# %%
import matplotlib.pyplot as plt

CV=[0.8968, 0.9521, 0.9609, 0.9646]
EV=[0.8934, 0.949, 0.9597, 0.9632]

x=[0.89, 0.9, 0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97]
y=[0.89, 0.9, 0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97]

plt.text(0.8968,0.8934,'SVM')
plt.text(0.9521,0.949,'random forest')
plt.text(0.9609,0.9597,'GCN',horizontalalignment='right')
plt.text(0.9646,0.9632,'GAT',horizontalalignment='right')

plt.scatter(CV, EV)
plt.plot(x,y)
plt.xlabel("Average F1-score of internal validation data for 5-fold cross validation")
plt.ylabel("F1-score of external test data")
# Out:
# Text(0, 0.5, 'F1-score of external test data')

# %%
CV2=[0.9561, 0.9992, 0.9322, 0.9347]
EV2=[0.9582, 0.9978, 0.9291, 0.9344]

x=[0.89, 0.9, 0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97, 0.98, 0.99, 1]
y=[0.89, 0.9, 0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97, 0.98, 0.99, 1]

plt.text(0.9561,0.9582,'SVM')
plt.text(0.9992,0.9978,'random forest',horizontalalignment='right')
plt.text(0.9322,0.9291,'GCN',horizontalalignment='right')
plt.text(0.9347,0.9344,'GAT',horizontalalignment='right')

plt.scatter(CV2, EV2)
plt.plot(x,y)
plt.xlabel("Average F1-score of internal validation data for 5-fold cross validation")
plt.ylabel("F1-score of external test data")
# Out:
# Text(0, 0.5, 'F1-score of external test data')
